# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %%
data=fetch_california_housing()
x=pd.DataFrame(data.data,columns=data.feature_names)
y=pd.Series(data.target,name='target')

# %%
scaler_X = StandardScaler()
scaler_y = StandardScaler()
x_scaled = scaler_X.fit_transform(x)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1)).flatten()

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %%
svr_model=SVR()
svr_model.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred=svr_model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)

# %%
plt.figure(figsize=(7,5))
plt.scatter(y_test, y_pred, alpha=0.5, edgecolor='k')
plt.xlabel("Actual (Scaled)")
plt.ylabel("Predicted (Scaled)")
plt.title("SVR: Predicted vs Actual Values")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-125-561ee7bcffce>:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(f"Mean Squared Error (scaled): {mse:.4f}")
# Out:
# Mean Squared Error (scaled): 0.3552

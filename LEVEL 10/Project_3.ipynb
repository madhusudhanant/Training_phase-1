# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# %%
data=pd.read_csv('/content/Supermart Grocery Sales - Retail Analytics Dataset.csv')

# %%
group1 = data[data['Region'] == 'North']['Sales']
group2 = data[data['Region'] == 'South']['Sales']

t_stat, p_value = ttest_ind(group1, group2)
print(f"t-statistic: {t_stat}, p-value: {p_value}")
# Out:
# t-statistic: -0.435752371536244, p-value: 0.6630745299503971

# %%
sns.barplot(x='Region', y='Sales', data=data)
plt.title('Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()
